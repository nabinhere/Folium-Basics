# %%
import folium

# %%
map = folium.Map(location=[27.620759026376376, 85.53959291408165], zoom_start=10)

# add separate layers for rectangles, lines, and polygons
rectangle_layer = folium.FeatureGroup(name="Rectangle Layer").add_to(map)
line_layer = folium.FeatureGroup(name="Line Layer").add_to(map)
polygon_layer = folium.FeatureGroup(name="Polygon Layer").add_to(map)
# add a rectangle to the rectangle layer
folium.Rectangle([[27.658844605753657, 85.32427081887934], [27.620739269895495, 85.53959482337858]],
                 color='red',
                 fill=True, fill_color='blue', fill_opacity=0.6).add_to(rectangle_layer)

# add lines to the line layer
folium.PolyLine([(27.658844605753657, 85.324270818879340), 
                 (27.620739269895495, 85.53959482337858),
                 (27.70614456268394, 85.3148035457928),
                ],
                 color='red',
                 weight=4.0).add_to(line_layer)

# add a polygon the the polygon layer
folium.Polygon([(27.73534209833566, 85.28080277528512), 
                 (27.620739269895495, 85.53959482337858),
                 (27.76328206411739, 85.44620962594186),
                (27.641685694197413, 85.36917658666898),
                ],
                 color='green', weight=4.0,
              fill=True, fill_color='orange', fill_opacity=0.4).add_to(polygon_layer)

# add layer control to the map
folium.LayerControl().add_to(map)

# %%
map.save("lines rects polygons.html")
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfe21d9e374385ea0b8fa725483bcb25 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfe21d9e374385ea0b8fa725483bcb25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfe21d9e374385ea0b8fa725483bcb25 = L.map(
#                 &quot;map_cfe21d9e374385ea0b8fa725483bcb25&quot;,
#                 {
#                     center: [27.620759026376376, 85.53959291408165],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e671b0a08b0fb3d8a0f3021c2cb0768 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5e671b0a08b0fb3d8a0f3021c2cb0768.addTo(map_cfe21d9e374385ea0b8fa725483bcb25);
#
#
#             var feature_group_e1903dcbddcad7619530d91bd35d61ef = L.featureGroup(
#                 {}
#             );
#
#
#             var rectangle_b748aa0a2e86c210f360c77382635dfd = L.rectangle(
#                 [[27.658844605753657, 85.32427081887934], [27.620739269895495, 85.53959482337858]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e1903dcbddcad7619530d91bd35d61ef);
#
#
#             feature_group_e1903dcbddcad7619530d91bd35d61ef.addTo(map_cfe21d9e374385ea0b8fa725483bcb25);
#
#
#             var feature_group_ca18f9a227301e7398f12d2c49fa7fa1 = L.featureGroup(
#                 {}
#             );
#
#
#             var poly_line_2b3314d50c03ca5e045aa080df1f4442 = L.polyline(
#                 [[27.658844605753657, 85.32427081887934], [27.620739269895495, 85.53959482337858], [27.70614456268394, 85.3148035457928]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4.0}
#             ).addTo(feature_group_ca18f9a227301e7398f12d2c49fa7fa1);
#
#
#             feature_group_ca18f9a227301e7398f12d2c49fa7fa1.addTo(map_cfe21d9e374385ea0b8fa725483bcb25);
#
#
#             var feature_group_5774d24d145c9239f9a1556374c6c18d = L.featureGroup(
#                 {}
#             );
#
#
#             var polygon_12d85c864e29342d086b5b0c39b3630e = L.polygon(
#                 [[27.73534209833566, 85.28080277528512], [27.620739269895495, 85.53959482337858], [27.76328206411739, 85.44620962594186], [27.641685694197413, 85.36917658666898]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4.0}
#             ).addTo(feature_group_5774d24d145c9239f9a1556374c6c18d);
#
#
#             feature_group_5774d24d145c9239f9a1556374c6c18d.addTo(map_cfe21d9e374385ea0b8fa725483bcb25);
#
#
#             var layer_control_462ab419955993fa393b02d4b9596008_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_5e671b0a08b0fb3d8a0f3021c2cb0768,
#                 },
#                 overlays :  {
#                     &quot;Rectangle Layer&quot; : feature_group_e1903dcbddcad7619530d91bd35d61ef,
#                     &quot;Line Layer&quot; : feature_group_ca18f9a227301e7398f12d2c49fa7fa1,
#                     &quot;Polygon Layer&quot; : feature_group_5774d24d145c9239f9a1556374c6c18d,
#                 },
#             };
#             let layer_control_462ab419955993fa393b02d4b9596008 = L.control.layers(
#                 layer_control_462ab419955993fa393b02d4b9596008_layers.base_layers,
#                 layer_control_462ab419955993fa393b02d4b9596008_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_cfe21d9e374385ea0b8fa725483bcb25)
